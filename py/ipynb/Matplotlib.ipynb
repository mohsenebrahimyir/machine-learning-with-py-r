# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
plt.plot([1,2,3,4])
plt.ylabel('funny numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [-1, 8, 1, 2])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [-1, 8, 1, 2], 'yo')
plt.plot([1, 2, 3, 4], [-7, 6, 1, 4], 'b+')

plt.show()

# %%
t = np.arange(0, 5, 0.2)
plt.plot(t, t**2, 'r--')plt.axis(**isfont)

plt.show()

# %%
xyfont = {'fontname':'XB Yas'}
isfont = {'fontname':'IRANSans'}

t = np.arange(0, 5, 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.title('title',**xyfont)
plt.xlabel('xlabel', **isfont)
plt.show()

# %%
data = {
    'a': np.arange(500),
    'b': np.random.randint(0, 50, 50),
    'c': np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])
plt.show()
